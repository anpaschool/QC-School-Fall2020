# %% [markdown]
# ## Contents
# 1. [Review of Single-Qubit States and Bloch-Sphere](#represent)
# 2. [Representing Two-Qubit States ](#represent)
#     2.1 [Hadamard-Gates](#Hadamard)
#     2.2 [CNOT-Gates](#CNOT)
# 3.  [Entangled States](#entangled)
#     3.1 [Bell-Gates](#Bell)
#
#
# ### Recall
# # 1. Single-Qubit state
#
# $ |\psi\rangle  =  a|0\rangle + b|1\rangle , \quad |a|^2 + |b|^2  = 1$
#
# $ |0\rangle  = \begin{bmatrix} 1 \\  0 \end{bmatrix} $
#
# $ |1\rangle  = \begin{bmatrix} 0 \\  1 \end{bmatrix} $
#
#
# $ |+\rangle  =  \tfrac{1}{\sqrt{2}}(|0\rangle + |1\rangle) = \tfrac{1}{\sqrt{2}}(\begin{bmatrix} 1 \\ 0 \end{bmatrix}+ \begin{bmatrix} 0 \\ 1 \end{bmatrix}) = \tfrac{1}{\sqrt{2}}\begin{bmatrix} 1 \\ 1 \end{bmatrix}$
#
# $ |-\rangle  =  \tfrac{1}{\sqrt{2}}(|0\rangle - |1\rangle) = \tfrac{1}{\sqrt{2}}(\begin{bmatrix} 1 \\ 0 \end{bmatrix}- \begin{bmatrix} 0 \\ 1 \end{bmatrix}) = \tfrac{1}{\sqrt{2}}\begin{bmatrix}  1 \\ -1 \end{bmatrix}$

# %% [markdown]
# ### Bloch_sphere
# ![Bloch_sphere](Figures/bloch_new.png)

# %% [markdown]
# ### Basis_axis_Bloch_sphere
#
# ![Bloch_sphere](Figures/basis_axis.png)

# %% [markdown]
# # Note:
# # Visualization of 1-Qubit statevectors: 2 computational basis |0> and |1> shown by two 2 arrows in +/- z-axis i.e. up-down direction.

# %% [markdown]
# ## 2. Representing Two-Qubit States <a id="represent"></a>
#
# We saw that a single bit has two possible states, and a qubit state has two complex amplitudes. Similarly, two bits have four possible states:
#
# `00` `01` `10` `11`
#
# $$ |00\rangle  = \begin{bmatrix} 1 \\ 0 \\ 0 \\ 0 \end{bmatrix},\quad |01\rangle  = \begin{bmatrix} 0 \\ 1 \\ 0 \\ 0 \end{bmatrix}, \quad |10\rangle  = \begin{bmatrix} 0 \\ 0 \\ 1 \\ 0 \end{bmatrix}, \quad|11\rangle  = \begin{bmatrix} 0 \\ 0 \\ 0 \\ 1 \end{bmatrix} $$
#
# And to describe the state of two qubits requires four complex amplitudes. We store these amplitudes in a 4D-vector like so:
#
# $$ |a\rangle = a_{00}|00\rangle + a_{01}|01\rangle + a_{10}|10\rangle + a_{11}|11\rangle  $$
#
#
# $$ |a_{00}|^2 + |a_{01}|^2 + |a_{10}|^2 + |a_{11}|^2 = 1$$
#
# If we have two separated qubits, we can describe their collective state using the tensor product:
#
# $$ |0\rangle = \begin{bmatrix} 1 \\ 0 \end{bmatrix}, \quad |1\rangle = \begin{bmatrix} 0 \\ 1 \end{bmatrix} $$
#
# $$
# |01\rangle = |0\rangle \otimes |1\rangle = \begin{bmatrix} 1 \times \begin{bmatrix} 0 \\ 1 \end{bmatrix} \\ 0 \times \begin{bmatrix} 0 \\ 1 \end{bmatrix} \end{bmatrix} = \begin{bmatrix} 0 \\ 1 \\ 0 \\ 0 \end{bmatrix}
# $$
#
# If we have $n$ qubits, we will need to keep track of $2^n$ complex amplitudes. As we can see, these vectors grow exponentially with the number of qubits. This is the reason quantum computers with large numbers of qubits are so difficult to simulate. A modern laptop can easily simulate a general quantum state of around 20 qubits, but simulating 100 qubits is too difficult for the largest supercomputers.

# %%
from qiskit import *
from math import pi
import numpy as np
from qiskit.quantum_info import Statevector
from qiskit_textbook.tools import array_to_latex
from qiskit.visualization import plot_bloch_multivector, plot_histogram, plot_state_city,plot_state_qsphere

# %matplotlib inline

# %% [markdown]
# # Visualization of 2-Qubit statevectors: 4 computational basis |00>, |01>, |10>, and |11> . Hence, we expect 4 vectors in Q-sphere. Similar to two computational basis in 1-qubit statevectors |0> and |1>, which are shown by 2 arrows in +/- Z-axis or in up-down direction.
# # 1. |00> = column-vector [1 0 0 0]
# $ |00\rangle  = \begin{bmatrix} 1 \\ 0 \\ 0 \\ 0 \end{bmatrix}$

# %%
qc1 = QuantumCircuit(2)
qc1.draw('mpl')

# %%
backend = Aer.get_backend('statevector_simulator') # Tell Qiskit how to simulate our circuit
final_state = execute(qc1,backend).result().get_statevector()
job = execute(qc1,backend).result() # Do the simulation, returning the state vector
print(final_state)
array_to_latex(final_state, pretext="\\text{Statevector} = ")
plot_state_qsphere(job.get_statevector(qc1))
# Out:
# [1.+0.j 0.+0.j 0.+0.j 0.+0.j]
# $\displaystyle
# \text{Statevector} = \begin{bmatrix}
# 1 \\
# 0 \\
# 0 \\
# 0
# \end{bmatrix}
# $

# %% [markdown]
# # 2. |01> = column-vector [0 1 0 0]
# $ |01\rangle  = \begin{bmatrix} 0 \\ 1 \\ 0 \\ 0 \end{bmatrix}$

# %%
qc1 = QuantumCircuit(2)
qc1.x(0)
qc1.draw('mpl')

# %%
backend = Aer.get_backend('statevector_simulator') # Tell Qiskit how to simulate our circuit
final_state = execute(qc1,backend).result().get_statevector()
job = execute(qc1,backend).result() # Do the simulation, returning the state vector
print(final_state)
array_to_latex(final_state, pretext="\\text{Statevector} = ")
plot_state_qsphere(job.get_statevector(qc1))
# Out:
# [0.+0.j 1.+0.j 0.+0.j 0.+0.j]
# $\displaystyle
# \text{Statevector} = \begin{bmatrix}
# 0 \\
# 1 \\
# 0 \\
# 0
# \end{bmatrix}
# $

# %% [markdown]
# # 3. |10> = column-vector [0 0 1 0]
# $ |10\rangle  = \begin{bmatrix} 0 \\ 0 \\ 1 \\ 0 \end{bmatrix}$

# %%
qc1 = QuantumCircuit(2)
qc1.x(1)
qc1.draw('mpl')

# %%
backend = Aer.get_backend('statevector_simulator') # Tell Qiskit how to simulate our circuit
final_state = execute(qc1,backend).result().get_statevector()
job = execute(qc1,backend).result() # Do the simulation, returning the state vector
print(final_state)
array_to_latex(final_state, pretext="\\text{Statevector = }")
plot_state_qsphere(job.get_statevector(qc1))
# Out:
# [0.+0.j 0.+0.j 1.+0.j 0.+0.j]
# $\displaystyle
# \text{Statevector = }\begin{bmatrix}
# 0 \\
# 0 \\
# 1 \\
# 0
# \end{bmatrix}
# $

# %% [markdown]
# # 4. |11> = column-vector [0 0 0 1]
# $ |11\rangle  = \begin{bmatrix} 0 \\ 0 \\ 0 \\ 1 \end{bmatrix}$

# %%
qc1 = QuantumCircuit(2)
qc1.x(0)
qc1.x(1)
qc1.draw('mpl')

# %%
backend = Aer.get_backend('statevector_simulator') # Tell Qiskit how to simulate our circuit
final_state = execute(qc1,backend).result().get_statevector()
job = execute(qc1,backend).result() # Do the simulation, returning the state vector
print(final_state)
array_to_latex(final_state, pretext="\\text{Statevector} = ")
plot_state_qsphere(job.get_statevector(qc1))
# Out:
# [0.+0.j 0.+0.j 0.+0.j 1.+0.j]
# $\displaystyle
# \text{Statevector} = \begin{bmatrix}
# 0 \\
# 0 \\
# 0 \\
# 1
# \end{bmatrix}
# $

# %% [markdown]
# ### Visualization of 2-Qubit statevectors:
#
# 4 computational basis |00>, |11>, |10>, and |01> span the space and we see 4 vectors . Hence, we see 4 vectors along up, down,right, and left respectively in the Q-sphere. It becomes more clear when we observe the visulaization of Bell-states in later section. The computational basis can be calculated by $2^N$ where N is the number of qubits. For example, when you have two qubits the computational basis is 4 qubits.

# %% [markdown]
# ### 3. Entangled States <a id="entangled"></a>
#
# We saw in the previous section we could create the state:
#
# $$
# \tfrac{1}{\sqrt{2}}(|00\rangle + |11\rangle)
# $$
#
# This is known as a _Bell_ state. We can see that this state has 50% probability of being measured in the state $|00\rangle$, and 50% chance of being measured in the state $|11\rangle$. Most interestingly, it has a **0%** chance of being measured in the states $|01\rangle$ or $|10\rangle$.

# %% [markdown]
# This combined state cannot be written as two separate qubit states, which has interesting implications. Although our qubits are in superposition, measuring one will tell us the state of the other and collapse its superposition. For example, if we measured the top qubit and got the state $|1\rangle$, the collective state of our qubits changes like so:
#
# $$
# \tfrac{1}{\sqrt{2}}(|00\rangle + |11\rangle) \quad \xrightarrow[]{\text{measure}} \quad |11\rangle
# $$
#
# Even if we separated these qubits light-years away, measuring one qubit collapses the superposition and appears to have an immediate effect on the other. This is the [‘spooky action at a distance’](https://en.wikipedia.org/wiki/Quantum_nonlocality) that upset so many physicists in the early 20th century.
#
# It’s important to note that the measurement result is random, and the measurement statistics of one qubit are **not** affected by any operation on the other qubit. Because of this, there is **no way** to use shared quantum states to communicate. This is known as the no-communication theorem.[1]

# %% [markdown]
# # Bell-state
# # Hadamard gate :
# $$
# \text{H}|0\rangle = \tfrac{1}{\sqrt{2}}(|0\rangle + |1\rangle) = |+\rangle
# $$
#
# $$
# \text{H}|1\rangle = \tfrac{1}{\sqrt{2}}(|0\rangle - |1\rangle) = |-\rangle
# $$
#
#
# # CNOT gate:
# $$
# \text{CNOT}|x1\rangle = \text{bit x flips}\
# $$
#
# ### Bell-Gates
# ![Bell-Gates](Figures/bell.png)

# %% [markdown]
# # (1) $\beta|00\rangle = \tfrac{1}{\sqrt{2}}(|00\rangle + |11\rangle)$

# %%
sv = Statevector.from_label('00')
# Bell State |Ψ+>
qcb = QuantumCircuit(2)
qcb.h(0)
qcb.cx(0, 1)
qcb.draw('mpl')

# %%
new_sv = sv.evolve(qcb)
print(new_sv)
plot_state_qsphere(new_sv.data)
# Out:
# Statevector([0.70710678+0.j 0.        +0.j 0.        +0.j 0.70710678+0.j], dims=(2, 2))

# %% [markdown]
# # Another Way

# %%
qc = QuantumCircuit(2)
# Apply H-gate to the first:
qc.h(0)
# Apply a CNOT:
qc.cx(0,1)
qc.draw('mpl')

# %%
backend = Aer.get_backend('statevector_simulator')
final_state = execute(qc,backend).result().get_statevector()
job = execute(qc,backend).result() # Do the simulation, returning the state vector
print(np.round(final_state,10))
array_to_latex(final_state, pretext="\\text{Statevector} = ")
plot_state_qsphere(job.get_statevector(qc))
# Out:
# [0.70710678+0.j 0.        +0.j 0.        +0.j 0.70710678+0.j]
# $\displaystyle
# \text{Statevector} = \begin{bmatrix}
# \tfrac{1}{\sqrt{2}} \\
# 0 \\
# 0 \\
# \tfrac{1}{\sqrt{2}}
# \end{bmatrix}
# $

# %% [markdown]
# # (2) $\beta|01\rangle = \tfrac{1}{\sqrt{2}}(|00\rangle - |11\rangle)$

# %%
sv = Statevector.from_label('01')
# Bell State |Ψ+>
qcx = QuantumCircuit(2)
qcx.h(0)
qcx.cx(0, 1)
qcx.draw('mpl')

# %%
new_sv = sv.evolve(qcx)
print(new_sv)
plot_state_qsphere(new_sv.data)
# Out:
# Statevector([ 0.70710678+0.j  0.        +0.j  0.        +0.j -0.70710678+0.j], dims=(2, 2))

# %% [markdown]
# # Another Way

# %%
qc = QuantumCircuit(2)
# Apply H-gate to the first:
qc.x(0)
qc.h(0)
# Apply a CNOT:
qc.cx(0,1)
qc.draw('mpl')

# %%
backend = Aer.get_backend('statevector_simulator')
final_state = execute(qc,backend).result().get_statevector()
job = execute(qc,backend).result() # Do the simulation, returning the state vector
print(np.round(final_state,10))
array_to_latex(final_state, pretext="\\text{Statevector} = ")
plot_state_qsphere(job.get_statevector(qc))
# Out:
# [ 0.70710678-0.j  0.        +0.j  0.        +0.j -0.70710678+0.j]
# $\displaystyle
# \text{Statevector} = \begin{bmatrix}
# \tfrac{1}{\sqrt{2}} \\
# 0 \\
# 0 \\
# -\tfrac{1}{\sqrt{2}}
# \end{bmatrix}
# $

# %% [markdown]
# # (3) $\beta|10\rangle = \tfrac{1}{\sqrt{2}}(|10\rangle + |01\rangle)$

# %%
sv = Statevector.from_label('10')
# Bell State |Ψ+>
qcx = QuantumCircuit(2)
qcx.h(0)
qcx.cx(0, 1)
qcx.draw('mpl')

# %%
new_sv = sv.evolve(qcx)
print(new_sv)
plot_state_qsphere(new_sv.data)
# Out:
# Statevector([0.        +0.j 0.70710678+0.j 0.70710678+0.j 0.        +0.j], dims=(2, 2))

# %% [markdown]
# # Another Way

# %%
qc = QuantumCircuit(2)
# Apply H-gate to the first:
qc.x(1)
qc.h(0)
# Apply a CNOT:
qc.cx(0,1)
qc.draw('mpl')

# %%
backend = Aer.get_backend('statevector_simulator')
final_state = execute(qc,backend).result().get_statevector()
job = execute(qc,backend).result() # Do the simulation, returning the state vector
print(np.round(final_state,10))
array_to_latex(final_state, pretext="\\text{Statevector} = ")
plot_state_qsphere(job.get_statevector(qc))
# Out:
# [0.        +0.j 0.70710678+0.j 0.70710678+0.j 0.        +0.j]
# $\displaystyle
# \text{Statevector} = \begin{bmatrix}
# 0 \\
# \tfrac{1}{\sqrt{2}} \\
# \tfrac{1}{\sqrt{2}} \\
# 0
# \end{bmatrix}
# $

# %% [markdown]
# # (4) $\beta|11\rangle = \tfrac{1}{\sqrt{2}}(|01\rangle - |10\rangle)$

# %%
sv = Statevector.from_label('11')
# Bell State |Ψ+>
qcx = QuantumCircuit(2)
qcx.h(0)
qcx.cx(0, 1)
qcx.draw('mpl')

# %%
new_sv = sv.evolve(qcx)
print(new_sv)
plot_state_qsphere(new_sv.data)
# Out:
# Statevector([ 0.        +0.j -0.70710678+0.j  0.70710678+0.j  0.        +0.j], dims=(2, 2))

# %% [markdown]
# # Another Way

# %%
qc = QuantumCircuit(2)
# Apply H-gate to the first:
qc.x(0)
qc.x(1)
qc.h(0)
# Apply a CNOT:
qc.cx(0,1)
qc.draw('mpl')

# %%
backend = Aer.get_backend('statevector_simulator')
final_state = execute(qc,backend).result().get_statevector()
job = execute(qc,backend).result() # Do the simulation, returning the state vector
print(np.round(final_state,10))
array_to_latex(final_state, pretext="\\text{Statevector} = ")
plot_state_qsphere(job.get_statevector(qc))
# Out:
# [ 0.        +0.j -0.70710678+0.j  0.70710678-0.j  0.        +0.j]
# $\displaystyle
# \text{Statevector} = \begin{bmatrix}
# 0 \\
# -\tfrac{1}{\sqrt{2}} \\
# \tfrac{1}{\sqrt{2}} \\
# 0
# \end{bmatrix}
# $

# %% [markdown]
# #### Entanglement : Situation where two or more qubits are so tightly correlated that we cannot learn something about one without learning about the other(s).
# #### 1. When the measurement value of one qubit is known, it uniquely determines the second.
# #### 2. If a 2-qubit quantum state is not entangled then we can separate it into the tensor product of two 1-qubit states. For this reason, if a quantum state is not entangled then it is separable. (page 280 Dancing with Qubits)
